# %% [markdown]
# <a href="https://colab.research.google.com/github/harshavardhinimodium/Typing-speed-calculator/blob/main/Python_for_Machine_Learning_25_29_Apr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Day 2**

# %% [markdown]
# # **Pandas**

# %% [markdown]
# # Example 1

# %%
import pandas as pd

# %%
df = pd.read_csv('https://github.com/ybifoundation/Dataset/raw/main/Fruits.csv'   )

# %%
df.head()
# Out:
#    Fruit Category Fruit Name  Fruit Weight  Fruit Width  Fruit Length  \
# 0               1      Apple           192          8.4           7.3
# 1               1      Apple           180          8.0           6.8
# 2               1      Apple           176          7.4           7.2
# 3               1      Apple           178          7.1           7.8
# 4               1      Apple           172          7.4           7.0
#
#    Fruit Colour Score
# 0                0.55
# 1                0.59
# 2                0.60
# 3                0.92
# 4                0.89

# %%
df1 = pd.read_csv('/content/Fruits.csv')

# %%
df1.head()
# Out:
#    Fruit Category Fruit Name  Fruit Weight  Fruit Width  Fruit Length  \
# 0               1      Apple           192          8.4           7.3
# 1               1      Apple           180          8.0           6.8
# 2               1      Apple           176          7.4           7.2
# 3               1      Apple           178          7.1           7.8
# 4               1      Apple           172          7.4           7.0
#
#    Fruit Colour Score
# 0                0.55
# 1                0.59
# 2                0.60
# 3                0.92
# 4                0.89

# %%
df.tail()
# Out:
#     Fruit Category Fruit Name  Fruit Weight  Fruit Width  Fruit Length  \
# 54               3      Lemon            58          6.1           8.5
# 55               3      Lemon            58          6.3           7.7
# 56               3      Lemon            58          5.9           8.1
# 57               3      Lemon            76          6.5           8.5
# 58               3      Lemon            59          6.1           8.1
#
#     Fruit Colour Score
# 54                0.71
# 55                0.72
# 56                0.73
# 57                0.72
# 58                0.70

# %%
df.sample(3)
# Out:
#     Fruit Category Fruit Name  Fruit Weight  Fruit Width  Fruit Length  \
# 11               1      Apple           156          7.6           7.5
# 37               2     Orange           154          7.3           7.3
# 28               2     Orange           140          6.7           7.1
#
#     Fruit Colour Score
# 11                0.67
# 37                0.79
# 28                0.72

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Fruit Category      59 non-null     int64
#  1   Fruit Name          59 non-null     object
#  2   Fruit Weight        59 non-null     int64
#  3   Fruit Width         59 non-null     float64
#  4   Fruit Length        59 non-null     float64
#  5   Fruit Colour Score  59 non-null     float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 2.9+ KB

# %%
missingdata = pd.read_csv('https://github.com/ybifoundation/Dataset/raw/main/Car%20Sales%20Missing%20Data.csv')

# %%
missingdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           951 non-null    object
#  1   Colour         950 non-null    object
#  2   Odometer (KM)  950 non-null    float64
#  3   Doors          950 non-null    float64
#  4   Price          950 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 39.2+ KB

# %%
missingdata.isna().sum()
# Out:
# Make             49
# Colour           50
# Odometer (KM)    50
# Doors            50
# Price            50
# dtype: int64

# %%
missingdata.notna().sum()
# Out:
# Make             951
# Colour           950
# Odometer (KM)    950
# Doors            950
# Price            950
# dtype: int64

# %%
missingdata.dropna()
# Out:
#        Make Colour  Odometer (KM)  Doors      Price
# 0    Nissan  Black        10148.0    4.0  Rs1366850
# 1    Toyota  White        10217.0    4.0  Rs1144150
# 2    Toyota  White        10247.0    4.0  Rs1628300
# 3     Honda  White        10953.0    4.0   Rs831800
# 4    Nissan   Blue        10954.0    4.0  Rs1521950
# ..      ...    ...            ...    ...        ...
# 944  Toyota   Blue       248447.0    4.0   Rs285400
# 946  Nissan  Black       248736.0    4.0   Rs417900
# 947  Toyota  White       248815.0    4.0   Rs489250
# 948   Honda   Blue       248899.0    4.0   Rs291700
# 949  Nissan   Blue       249860.0    4.0   Rs726200
#
# [773 rows x 5 columns]

# %%
pd.options.display.max_rows = 100

# %%
missingdata.dropna()

# %%
df.head()
# Out:
#    Fruit Category Fruit Name  Fruit Weight  Fruit Width  Fruit Length  \
# 0               1      Apple           192          8.4           7.3
# 1               1      Apple           180          8.0           6.8
# 2               1      Apple           176          7.4           7.2
# 3               1      Apple           178          7.1           7.8
# 4               1      Apple           172          7.4           7.0
#
#    Fruit Colour Score
# 0                0.55
# 1                0.59
# 2                0.60
# 3                0.92
# 4                0.89

# %%
df.drop(['Fruit Name'], axis = 1)
# Out:
#     Fruit Category  Fruit Weight  Fruit Width  Fruit Length  \
# 0                1           192          8.4           7.3
# 1                1           180          8.0           6.8
# 2                1           176          7.4           7.2
# 3                1           178          7.1           7.8
# 4                1           172          7.4           7.0
# ..             ...           ...          ...           ...
# 54               3            58          6.1           8.5
# 55               3            58          6.3           7.7
# 56               3            58          5.9           8.1
# 57               3            76          6.5           8.5
# 58               3            59          6.1           8.1
#
#     Fruit Colour Score
# 0                 0.55
# 1                 0.59
# 2                 0.60
# 3                 0.92
# 4                 0.89
# ..                 ...
# 54                0.71
# 55                0.72
# 56                0.73
# ...

# %%
df_deleted = df.drop(['Fruit Name', 'Fruit Category'], axis = 1)

# %%
df_deleted.head()
# Out:
#    Fruit Weight  Fruit Width  Fruit Length  Fruit Colour Score
# 0           192          8.4           7.3                0.55
# 1           180          8.0           6.8                0.59
# 2           176          7.4           7.2                0.60
# 3           178          7.1           7.8                0.92
# 4           172          7.4           7.0                0.89

# %%
df.head()
# Out:
#    Fruit Category Fruit Name  Fruit Weight  Fruit Width  Fruit Length  \
# 0               1      Apple           192          8.4           7.3
# 1               1      Apple           180          8.0           6.8
# 2               1      Apple           176          7.4           7.2
# 3               1      Apple           178          7.1           7.8
# 4               1      Apple           172          7.4           7.0
#
#    Fruit Colour Score
# 0                0.55
# 1                0.59
# 2                0.60
# 3                0.92
# 4                0.89

# %%
df.describe()
# Out:
#        Fruit Category  Fruit Weight  Fruit Width  Fruit Length  \
# count       59.000000     59.000000    59.000000     59.000000
# mean         1.949153    141.796610     7.105085      7.693220
# std          0.775125     67.335951     0.816938      1.361017
# min          1.000000     58.000000     5.800000      4.000000
# 25%          1.000000     82.000000     6.600000      7.200000
# 50%          2.000000    154.000000     7.200000      7.600000
# 75%          3.000000    167.000000     7.500000      8.200000
# max          3.000000    362.000000     9.600000     10.500000
#
#        Fruit Colour Score
# count           59.000000
# mean             0.762881
# std              0.076857
# min              0.550000
# 25%              0.720000
# 50%              0.750000
# 75%              0.810000
# max              0.930000

# %%
missingdata.head()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Nissan  Black        10148.0    4.0  Rs1366850
# 1  Toyota  White        10217.0    4.0  Rs1144150
# 2  Toyota  White        10247.0    4.0  Rs1628300
# 3   Honda  White        10953.0    4.0   Rs831800
# 4  Nissan   Blue        10954.0    4.0  Rs1521950

# %%
missingdata[['Make', 'Colour']].value_counts()
# Out:
# Make    Colour
# Toyota  White     144
#         Blue      114
# Honda   White     110
#         Blue       89
# Nissan  White      76
#         Blue       54
# Toyota  Black      40
# BMW     White      35
# Toyota  Green      33
#         Red        32
# BMW     Blue       30
# Honda   Black      29
#         Red        24
#         Green      18
# Nissan  Red        17
#         Green      16
#         Black      14
# BMW     Red        13
#         Black       8
#         Green       6
# dtype: int64

# %%
missingdata[['Make', 'Colour']]
# Out:
#        Make Colour
# 0    Nissan  Black
# 1    Toyota  White
# 2    Toyota  White
# 3     Honda  White
# 4    Nissan   Blue
# ..      ...    ...
# 995  Toyota  White
# 996  Toyota  White
# 997     BMW  White
# 998  Toyota  White
# 999  Toyota  White
#
# [1000 rows x 2 columns]

# %%
missingdata['Make'].unique()
# Out:
# array(['Nissan', 'Toyota', 'Honda', 'BMW', nan], dtype=object)

# %%
missingdata['Make'].nunique()
# Out:
# 4

# %%
missingdata.sort_values(['Odometer (KM)', 'Price'])
# Out:
#        Make Colour  Odometer (KM)  Doors      Price
# 0    Nissan  Black        10148.0    4.0  Rs1366850
# 1    Toyota  White        10217.0    4.0  Rs1144150
# 2    Toyota  White        10247.0    4.0  Rs1628300
# 3     Honda  White        10953.0    4.0   Rs831800
# 4    Nissan   Blue        10954.0    4.0  Rs1521950
# ..      ...    ...            ...    ...        ...
# 944  Toyota   Blue       248447.0    4.0   Rs285400
# 946  Nissan  Black       248736.0    4.0   Rs417900
# 947  Toyota  White       248815.0    4.0   Rs489250
# 948   Honda   Blue       248899.0    4.0   Rs291700
# 949  Nissan   Blue       249860.0    4.0   Rs726200
#
# [773 rows x 5 columns]

# %%
missingdata = missingdata.dropna()

# %%
missingdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 773 entries, 0 to 949
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           773 non-null    object
#  1   Colour         773 non-null    object
#  2   Odometer (KM)  773 non-null    float64
#  3   Doors          773 non-null    float64
#  4   Price          773 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 36.2+ KB

# %%
missingdata['calculated column'  ] =missingdata['Doors']/missingdata['Odometer (KM)']*100

# %%
missingdata.head()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Nissan  Black        10148.0    4.0  Rs1366850
# 1  Toyota  White        10217.0    4.0  Rs1144150
# 2  Toyota  White        10247.0    4.0  Rs1628300
# 3   Honda  White        10953.0    4.0   Rs831800
# 4  Nissan   Blue        10954.0    4.0  Rs1521950

# %%
missingdata.head()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  calculated column
# 0  Nissan  Black        10148.0    4.0  Rs1366850           0.039417
# 1  Toyota  White        10217.0    4.0  Rs1144150           0.039150
# 2  Toyota  White        10247.0    4.0  Rs1628300           0.039036
# 3   Honda  White        10953.0    4.0   Rs831800           0.036520
# 4  Nissan   Blue        10954.0    4.0  Rs1521950           0.036516

# %%
titanic = pd.read_csv('https://github.com/ybifoundation/Dataset/raw/main/Titanic.csv')

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
titanic.loc[  :  ,  :  ]

# %%
titanic.iloc[  :   ,   :  ]

# %%
titanic.loc[  1: 4  ,   :   ] # label
# Out:
#    pclass  survived                                             name     sex  \
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket    fare    cabin embarked boat   body  \
# 1   0.92      1      2  113781  151.55  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.55  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.55  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.55  C22 C26        S  NaN    NaN
#
#                          home.dest
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
titanic.iloc[1  : 5    ,  :   ] # index
# Out:
#    pclass  survived                                             name     sex  \
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket    fare    cabin embarked boat   body  \
# 1   0.92      1      2  113781  151.55  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.55  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.55  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.55  C22 C26        S  NaN    NaN
#
#                          home.dest
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
titanic.loc[  1: 4  ,  'pclass' : 'name'  ] # label

# %%
titanic.iloc[1  : 5    , 0   : 3  ] # index

# %%
titanic.loc[  1: 4  ,  [ 'name', 'pclass']  ] # label

# %%
titanic.iloc[1  : 5    , [ 2, 0]  ] # index

# %%
titanic.head()

# %%
titanic.loc[titanic['sex']=='female',   :]

# %%
titanic.loc[(titanic['sex']=='female') & (titanic['age']>60) & (titanic['pclass']==1),   :]
# Out:
#      pclass  survived                                               name  \
# 6         1         1                  Andrews, Miss. Kornelia Theodosia
# 61        1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 78        1         1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# 83        1         1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
# 284       1         1          Stone, Mrs. George Nelson (Martha Evelyn)
# 286       1         0             Straus, Mrs. Isidor (Rosalie Ida Blun)
#
#         sex   age  sibsp  parch    ticket      fare    cabin embarked boat  \
# 6    female  63.0      1      0     13502   77.9583       D7        S   10
# 61   female  76.0      1      0     19877   78.8500      C46        S    6
# 78   female  64.0      0      2  PC 17756   83.1583      E45        C   14
# 83   female  64.0      1      1    112901   26.5500      B26        S    7
# 284  female  62.0      0      0    113572   80.0000      B28      NaN    6
# ...
